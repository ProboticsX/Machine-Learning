# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import math

# %% [markdown]
# MSE = 1/n(E(y-yp)^2)
# MSE or cost function = 1/n(E(y-(mx+b)^2)

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.49.48 AM.png](data:image/png;base64,...)

# %% [markdown]
# Gradient Descent is an algorithm that finds the best fit line for given training data set. We take a point say "*" and try to move towards our training data using baby steps which decrease as we go down.
#
# We take partial derivatives because that what helps in calculating the slope and hence the next point.
#
# Repeat the same exercise for MSE vs m

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 1000000
  n = len(x)
  cost_previous = 0
  learning_rate = 0.0002
  for i in range(iterations):
    y_predicted = m_curr*x+b_curr
    cost = (1/n)*sum(val**2 for val in (y-y_predicted))
    md = -(2/n)*sum(x*(y-y_predicted))
    bd = -(2/n)*sum(y-y_predicted)
    m_curr = m_curr-learning_rate*md
    b_curr = b_curr-learning_rate*bd
    if math.isclose(cost, cost_previous, rel_tol=1e-20):
      break
    cost_previous = cost
    print ("m {}, b {}, cost {}, iteration {}".format(m_curr, b_curr, cost, i))
    plt.plot(x, y_predicted, color='green')


# x = np.array([1,2,3,4,5])
# y = np.array([5,7,9,11,13])
# # m = 2, b = 3
# plt.xlabel('x')
# plt.ylabel('y')
# gradient_descent(x,y)

# plt.scatter(x, y, color='red', marker='+')
# plt.plot(x, y, color='blue')

# %%
test_scores_df = pd.read_csv("sample_data/test_scores.csv")
test_scores_df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x = test_scores_df['math']
y = test_scores_df['cs']

plt.xlabel('math')
plt.ylabel('cs')
gradient_descent(x,y)

plt.scatter(x, y, color='red', marker='+')
# Out:
# Streaming output truncated to the last 5000 lines.
# m 1.0177384013606576, b 1.915065989263764, cost 31.60451133487914, iteration 410533
# m 1.0177384013109885, b 1.9150659927837017, cost 31.604511334879064, iteration 410534
# m 1.0177384012613204, b 1.9150659963035586, cost 31.60451133487899, iteration 410535
# m 1.017738401211653, b 1.9150659998233346, cost 31.60451133487895, iteration 410536
# m 1.0177384011619872, b 1.9150660033430298, cost 31.604511334878886, iteration 410537
# m 1.0177384011123225, b 1.9150660068626444, cost 31.60451133487882, iteration 410538
# m 1.0177384010626587, b 1.9150660103821782, cost 31.604511334878765, iteration 410539
# m 1.0177384010129964, b 1.9150660139016311, cost 31.604511334878694, iteration 410540
# m 1.0177384009633348, b 1.9150660174210032, cost 31.60451133487865, iteration 410541
# m 1.017738400913675, b 1.9150660209402945, cost 31.60451133487858, iteration 410542
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(test_scores_df[['math']],test_scores_df['cs'])
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# 1.9152193111569034

# %%
reg.coef_
# Out:
# array([1.01773624])
